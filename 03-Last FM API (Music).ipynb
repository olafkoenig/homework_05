# %% [markdown]
# # Last FM API (Music)
#
# Spotify's API is dead to us, so we're using Last.fm's - it's still music, just not as nice of an API.
#
# 1. Create an account at https://www.last.fm/api/
# 2. Create an "application" to get a key: https://www.last.fm/api/account/create
#     - It isn't a real application, it's just your project
#     - Name/description doesn't matter, ignore callback key and callback url
# 3. And save the API key that shows up on the next screen
#
# You can find documentation at https://www.last.fm/api/
#
# The domain for the API is `http://ws.audioscrobbler.com`, so all of your endpoints will be connected to that. To test your API key, check the following URL in your browser: `http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=cher&api_key=XXXXXXXXXXXXXXXXXXXX&format=json` (change the `XXXXXX` to be your API key, of course!).
#
# > Last.fm used to be called **AudioScrobbler**, which is why its URLs don't have "last.fm" in them.
# > While we're asking about URLs, notice that the API endpoints have a lot of `?` and `&` in them - these are key/value pairs, kind of like dictionaries, but for URLs instead of Python.

# %% [markdown]
# # FIRST: SETUP

# %% [markdown]
# ## 1) Import the libraries/packages you might need
#
# We need a library to read in the data for us! We don't like `urllib2`, so it must be something cooler and better.

# %%
# Import what you need here

import requests

from dotenv import load_dotenv
import os

from pprint import pprint


load_dotenv()  # take environment variables

API_LAST_FM = os.getenv("API_LAST_FM")

# %% [markdown]
# ## 2) Save your API key
#
# Write your API key here so you don't forget it - it's the "api key" one, not the "shared secret" one

# %%
API_LAST_FM = os.getenv("API_LAST_FM")

# %% [markdown]
# ## 3) The death of an API
#
# I used to have some code here that allowed you to display images, but _the images don't work any more._ Let this be an important lesson: when you depend on external services, they can die at any time.

# %% [markdown]
# # NOW: YOUR ASSIGNMENT

# %% [markdown]
# ## 1) Search for and print a list of 50 musicians with `lil` in their name, along with the number of listeners they have
#
# There are a lot of musicians with "Lil" in their name - it used to be all Lil Wayne and Lil Kim, but we live in a new world now!
#
# - *Tip: Remember, the domain for the API is `http://ws.audioscrobbler.com`*
# - *Tip: Make sure you ask the API for 50 musicians! This involves adding another parameter to the URL - notice they all have a `&` before them. [Read the documentation](http://www.last.fm/api/show/artist.search) to find the parameter's name.*
# - *Tip: When you are looking at any piece of data - is it a dictionary? Look at the keys! Is it a list? Look at the first element!*
# - *Tip: LOOK AT THE KEYS. and then the other keys and the other keys and the other keys. It's an ugly series of dictionaries!*

# %%
# http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=cher&api_key=99f32782a7be8554947b8c349742ead2&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=cher&api_key=YOUR_API_KEY&format=json

# %%
search_name = "lil"

url = f"http://ws.audioscrobbler.com/2.0/?method=artist.search&artist={search_name}&api_key={API_LAST_FM}&limit=50&format=json"

response = requests.get(url)

data_lil = response.json()

# %%
pprint(data_lil)
# Out:
# {'results': {'@attr': {'for': 'lil'},
#              'artistmatches': {'artist': [{'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '2304823',
#                                            'mbid': '',
#                                            'name': 'LIL UZI VERT',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+UZI+VERT'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '1805342',
#                                            'mbid': '',
#                                            'name': 'LIL PEEP',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+PEEP'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '1369262',
#                                            'mbid': '',
#                                            'name': 'Lil Baby',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Baby'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '1467941',
#                                            'mbid': '',
#                                            'name': 'Lil Tecca',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Tecca'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '1562507',
#                                            'mbid': '',
#                                            'name': 'Lil Yachty',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Yachty'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '2345381',
#                                            'mbid': '',
#                                            'name': 'Lil Nas X',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Nas+X'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '1879540',
#                                            'mbid': 'ac9a487a-d9d2-4f27-bb23-0f4686488345',
#                                            'name': 'Lil Wayne',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Wayne'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '3244734',
#                                            'mbid': '6e0c7c0e-cba5-4c2c-a652-38f71ef5785d',
#                                            'name': 'Lily Allen',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lily+Allen'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '954161',
#                                            'mbid': 'c9cd225b-4883-428e-82c2-73e0b6282fb6',
#                                            'name': 'Lil Durk',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Durk'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '845500',
#                                            'mbid': '',
#                                            'name': 'lil tjay',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/lil+tjay'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '588421',
#                                            'mbid': '',
#                                            'name': 'Lil Darkie',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Darkie'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '3385793',
#                                            'mbid': '',
#                                            'name': "Lil' Wayne",
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil%27+Wayne'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '723455',
#                                            'mbid': '',
#                                            'name': 'lil skies',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/lil+skies'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '357061',
#                                            'mbid': '5f1adfe1-4d07-4141-b181-79e5d379d539',
#                                            'name': 'Lil Ugly Mane',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Ugly+Mane'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '619149',
#                                            'mbid': '1550f952-c91b-40d7-9b4d-d26a259ee932',
#                                            'name': 'Lil B',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+B'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '837871',
#                                            'mbid': '',
#                                            'name': 'lil Mosey',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/lil+Mosey'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '128230',
#                                            'mbid': 'd4c7d574-c8f8-4c7e-ab45-fc612df367ca',
#                                            'name': 'Lil Shine',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Shine'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '301636',
#                                            'mbid': '',
#                                            'name': 'LIL TRACY',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+TRACY'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '635101',
#                                            'mbid': '',
#                                            'name': 'LIL PUMP',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+PUMP'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '315567',
#                                            'mbid': '',
#                                            'name': 'Lil Keed',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Keed'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '257801',
#                                            'mbid': '5652bb3e-f225-49de-9637-5aa1539b4a7c',
#                                            'name': 'Lily Chou-Chou',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lily+Chou-Chou'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '619158',
#                                            'mbid': '3268f062-6e76-480a-a384-e1dd2a276afb',
#                                            'name': 'Lil Dicky',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Dicky'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '384648',
#                                            'mbid': '',
#                                            'name': 'lil mabu',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/lil+mabu'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '269675',
#                                            'mbid': '',
#                                            'name': 'Lil Loaded',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Loaded'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '427602',
#                                            'mbid': '',
#                                            'name': 'Lil Xan',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Xan'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '705671',
#                                            'mbid': 'bc1b5c95-e6d6-46b5-957a-5e8908b02c1e',
#                                            'name': "Lil' Kim",
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil%27+Kim'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '253413',
#                                            'mbid': '',
#                                            'name': 'lilbubblegum',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/lilbubblegum'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '134745',
#                                            'mbid': '',
#                                            'name': 'Lilypichu',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lilypichu'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '352707',
#                                            'mbid': '',
#                                            'name': 'LIL GNAR',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+GNAR'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '68779',
#                                            'mbid': '',
#                                            'name': 'Lil Revive',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Revive'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '881036',
#                                            'mbid': '243c6f61-d83b-4459-bebd-5899df0da111',
#                                            'name': 'Lil Jon & The East Side '
#                                                    'Boyz',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Jon+&+The+East+Side+Boyz'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '135225',
#                                            'mbid': '',
#                                            'name': 'Lil Hero',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Hero'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '173445',
#                                            'mbid': '',
#                                            'name': 'LIL DUSTY G',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+DUSTY+G'},
# ...
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '254590',
#                                            'mbid': '',
#                                            'name': 'Lil Eazzyy',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Eazzyy'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '218302',
#                                            'mbid': '',
#                                            'name': 'Lil Candy Paint',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Candy+Paint'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '443487',
#                                            'mbid': '1b72331b-3a97-4981-a81c-eeee9c275d28',
#                                            'name': 'Lilly Wood & The Prick',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lilly+Wood+&+The+Prick'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '120983',
#                                            'mbid': '',
#                                            'name': 'LIL BO WEEP',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+BO+WEEP'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '294859',
#                                            'mbid': '',
#                                            'name': 'Fenne Lily',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Fenne+Lily'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '199495',
#                                            'mbid': '',
#                                            'name': 'LIL BOODANG',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/LIL+BOODANG'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '777796',
#                                            'mbid': 'a95384b1-6aec-468c-ae0d-8c6daf87c4c2',
#                                            'name': 'Lil Jon',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Jon'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '157555',
#                                            'mbid': '',
#                                            'name': 'Lil God Dan',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+God+Dan'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '54621',
#                                            'mbid': '',
#                                            'name': 'Lil O',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+O'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '229869',
#                                            'mbid': '',
#                                            'name': 'Lily James',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lily+James'},
#                                           {'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'small'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'medium'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'large'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'extralarge'},
#                                                      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#                                                       'size': 'mega'}],
#                                            'listeners': '160153',
#                                            'mbid': '',
#                                            'name': 'Lil Mariko',
#                                            'streamable': '0',
#                                            'url': 'https://www.last.fm/music/Lil+Mariko'}]},
#              'opensearch:Query': {'#text': '',
#                                   'role': 'request',
#                                   'searchTerms': 'lil',
#                                   'startPage': '1'},
#              'opensearch:itemsPerPage': '50',
#              'opensearch:startIndex': '0',
#              'opensearch:totalResults': '712620'}}

# %%
# pprint(data_lil['results']['artistmatches']['artist'][0])

list_lil = {}

for artist in data_lil['results']['artistmatches']['artist']:
    artist_name = artist['name']
    listeners = int(artist['listeners'])
    # url_image = artist['image'][3]['#text']
    print(f"{artist_name} has {listeners:,} listeners.")
    list_lil[artist_name] = listeners


print(f"________\nThis list contains {len(list_lil)} artists with a name containing 'Lil'.")
# print(list_lil)
# Out:
# LIL UZI VERT has 2,304,823 listeners.
# LIL PEEP has 1,805,342 listeners.
# Lil Baby has 1,369,262 listeners.
# Lil Tecca has 1,467,941 listeners.
# Lil Yachty has 1,562,507 listeners.
# Lil Nas X has 2,345,381 listeners.
# Lil Wayne has 1,879,540 listeners.
# Lily Allen has 3,244,734 listeners.
# Lil Durk has 954,161 listeners.
# lil tjay has 845,500 listeners.
# Lil Darkie has 588,421 listeners.
# Lil' Wayne has 3,385,793 listeners.
# lil skies has 723,455 listeners.
# Lil Ugly Mane has 357,061 listeners.
# Lil B has 619,149 listeners.
# lil Mosey has 837,871 listeners.
# Lil Shine has 128,230 listeners.
# LIL TRACY has 301,636 listeners.
# LIL PUMP has 635,101 listeners.
# Lil Keed has 315,567 listeners.
# Lily Chou-Chou has 257,801 listeners.
# Lil Dicky has 619,158 listeners.
# lil mabu has 384,648 listeners.
# Lil Loaded has 269,675 listeners.
# Lil Xan has 427,602 listeners.
# Lil' Kim has 705,671 listeners.
# lilbubblegum has 253,413 listeners.
# Lilypichu has 134,745 listeners.
# LIL GNAR has 352,707 listeners.
# Lil Revive has 68,779 listeners.
# Lil Jon & The East Side Boyz has 881,036 listeners.
# Lil Hero has 135,225 listeners.
# LIL DUSTY G has 173,445 listeners.
# Lil Double 0 has 125,027 listeners.
# Lil Tony Official has 79,536 listeners.
# Lilac has 330,276 listeners.
# Lil Kleine has 135,671 listeners.
# lilgiela33 has 26,464 listeners.
# Lilly Wood and The Prick has 396,805 listeners.
# Lil Eazzyy has 254,590 listeners.
# Lil Candy Paint has 218,302 listeners.
# Lilly Wood & The Prick has 443,487 listeners.
# LIL BO WEEP has 120,983 listeners.
# Fenne Lily has 294,859 listeners.
# LIL BOODANG has 199,495 listeners.
# Lil Jon has 777,796 listeners.
# Lil God Dan has 157,555 listeners.
# Lil O has 54,621 listeners.
# Lily James has 229,869 listeners.
# Lil Mariko has 160,153 listeners.
# ________
# This list contains 50 artists with a name containing 'Lil'.

# %% [markdown]
# Your results should begin something like this:
#
# ```
# Lil' Wayne has 3086628 listeners
# Lily Allen has 2074266 listeners
# Lil B has 194116 listeners
# Lilly Wood & The Prick has 359886 listeners
# Lil Ugly Mane has 31955 listeners
# LIL UZI VERT has 88517 listeners
# ```

# %% [markdown]
# ## 2) How many listeners does your list have in total?
#
# The answer should be more than **15,000,000**. If it's lower, make sure you have 50 artists instead of 30 artists.
#
# - *Tip: What's the data type of the `listeners` count? It's going to cause a problem!*
# - *Tip: If you were crazy you could use sum and a list comprehension. But you really don't have to!*

# %%
print(f"The list counts {sum(list_lil.values()):,} listeners.")
# Out:
# The list counts 34,340,869 listeners.

# %% [markdown]
# ## 3) Show each artist's name and the URL to the extra-large image
#
# The images don't work any more, but we'll print their URLs out anyway.

# %% [markdown]
# Each artist **has a list of images of different sizes**. We're interested in the second-to-last one, where `size` is `extralarge`. Print their name and use `display_image` to display their extra-large image.
#
# - *Tip: The URL should look like this: `https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png`*
# - *Tip: You can always assume it's the second to the last, or assume it's `extralarge`, or whatever you want to do to find it.*
# - *Tip: Make sure the URL is correct before you try to display it.*
#
# Your output should look something like
#
# ```
# Lil' Wayne
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ---
# LIL UZI VERT
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ---
# Lily Allen
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ---
# ```
#
# (but with more people, obviously)

# %%
# SAME URL for every artists (by default imgage...)

for artist in data_lil['results']['artistmatches']['artist']:
    artist_name = artist['name']
    # listeners = int(artist['listeners'])
    url_image = artist['image'][3]['#text']
    print(f"________\n{artist_name} \n{url_image}")
# Out:
# ________
# LIL UZI VERT
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# LIL PEEP
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Baby
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Tecca
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Yachty
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Nas X
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Wayne
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lily Allen
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Durk
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# lil tjay
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Darkie
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil' Wayne
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# lil skies
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Ugly Mane
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil B
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# lil Mosey
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Shine
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# LIL TRACY
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# LIL PUMP
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Keed
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lily Chou-Chou
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Dicky
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# lil mabu
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Loaded
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Xan
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil' Kim
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# lilbubblegum
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lilypichu
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# LIL GNAR
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Revive
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Jon & The East Side Boyz
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Hero
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# LIL DUSTY G
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Double 0
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Tony Official
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lilac
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Kleine
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# lilgiela33
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lilly Wood and The Prick
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Eazzyy
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Candy Paint
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lilly Wood & The Prick
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# LIL BO WEEP
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Fenne Lily
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# LIL BOODANG
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Jon
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil God Dan
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil O
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lily James
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ________
# Lil Mariko
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png

# %% [markdown]
# ## 4) Find Lil Jon's `mbid` (or anyone else's!).
#
# Oftentimes in an API, you can do a few things: you can **search** for items, and you can **see more information** about items. To find more information about the item, you need to use their **unique id**. In this dataset, it's called an `mbid` (MusicBrainz, I think - another company associated with last.fm!).
#
# Go through the artists and print their **name and mbid**. Find Lil Jon's `mbid`. I *wanted* Lil Uzi Vert's, but for some reason it isn't there. Then I wanted us to look at Lily Allen's, but I just couldn't bring myself to do that. If you'd rather do someone else, go for it.

# %%
# Create a list from dictionnary
all_lil_name_raw = list(list_lil.keys())

all_lil_name_edited = []

for artist in list_lil:
    name = artist.lower()
    name = name.replace(" ", "+")
    all_lil_name_edited.append(name)

# all_lil_name_clean = all_lil_name.lower().replace(" ", "+")
print(all_lil_name_edited)
# Out:
# ['lil+uzi+vert', 'lil+peep', 'lil+baby', 'lil+tecca', 'lil+yachty', 'lil+nas+x', 'lil+wayne', 'lily+allen', 'lil+durk', 'lil+tjay', 'lil+darkie', "lil'+wayne", 'lil+skies', 'lil+ugly+mane', 'lil+b', 'lil+mosey', 'lil+shine', 'lil+tracy', 'lil+pump', 'lil+keed', 'lily+chou-chou', 'lil+dicky', 'lil+mabu', 'lil+loaded', 'lil+xan', "lil'+kim", 'lilbubblegum', 'lilypichu', 'lil+gnar', 'lil+revive', 'lil+jon+&+the+east+side+boyz', 'lil+hero', 'lil+dusty+g', 'lil+double+0', 'lil+tony+official', 'lilac', 'lil+kleine', 'lilgiela33', 'lilly+wood+and+the+prick', 'lil+eazzyy', 'lil+candy+paint', 'lilly+wood+&+the+prick', 'lil+bo+weep', 'fenne+lily', 'lil+boodang', 'lil+jon', 'lil+god+dan', 'lil+o', 'lily+james', 'lil+mariko']

# %%
mbid_dict = {}

for artist in all_lil_name_edited:
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artist}&api_key={API_LAST_FM}&format=json"
    response = requests.get(url)

    try:
        data_artist_info = response.json()

        if 'artist' in data_artist_info:
            artist_info = data_artist_info['artist']
            artist_name = artist_info.get('name', artist)
            mbid = artist_info.get('mbid', None)

            mbid_dict[artist_name] = mbid
            if not mbid:
                print(f"No MBID for : {artist_name}")
            else:
                print(f"{artist_name} — MBID : {mbid}")

        else:
            print(f"Reponse problem for : {artist}")
            mbid_dict[artist] = None 

    except Exception as e:
        print(f"Error for {artist} : {e}")
        mbid_dict[artist] = None 


# Affichage final
pprint(mbid_dict, indent=4)
# Out:
# No MBID for : LIL UZI VERT
# No MBID for : LIL PEEP
# No MBID for : Lil Baby
# No MBID for : Lil Tecca
# No MBID for : Lil Yachty
# No MBID for : Lil Nas X
# Lil Wayne — MBID : ac9a487a-d9d2-4f27-bb23-0f4686488345
# Lily Allen — MBID : 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# Lil Durk — MBID : c9cd225b-4883-428e-82c2-73e0b6282fb6
# No MBID for : lil tjay
# No MBID for : Lil Darkie
# No MBID for : Lil' Wayne
# No MBID for : lil skies
# Lil Ugly Mane — MBID : 5f1adfe1-4d07-4141-b181-79e5d379d539
# Lil B — MBID : 1550f952-c91b-40d7-9b4d-d26a259ee932
# No MBID for : lil Mosey
# Lil Shine — MBID : d4c7d574-c8f8-4c7e-ab45-fc612df367ca
# No MBID for : LIL TRACY
# No MBID for : LIL PUMP
# No MBID for : Lil Keed
# Lily Chou-Chou — MBID : 5652bb3e-f225-49de-9637-5aa1539b4a7c
# Lil Dicky — MBID : 3268f062-6e76-480a-a384-e1dd2a276afb
# No MBID for : lil mabu
# No MBID for : Lil Loaded
# No MBID for : Lil Xan
# Lil' Kim — MBID : bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# No MBID for : lilbubblegum
# No MBID for : Lilypichu
# No MBID for : LIL GNAR
# No MBID for : Lil Revive
# No MBID for : Lil Jon
# No MBID for : Lil Hero
# No MBID for : LIL DUSTY G
# No MBID for : Lil Double 0
# No MBID for : Lil Tony Official
# Lilac — MBID : 1967c6ce-95a4-48f0-8ac7-abe637524aee
# No MBID for : Lil Kleine
# No MBID for : lilgiela33
# No MBID for : Lilly Wood and The Prick
# No MBID for : Lil Eazzyy
# No MBID for : Lil Candy Paint
# No MBID for : Lilly Wood
# No MBID for : LIL BO WEEP
# No MBID for : Fenne Lily
# No MBID for : LIL BOODANG
# Lil Jon — MBID : a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# No MBID for : Lil God Dan
# No MBID for : Lil O
# No MBID for : Lily James
# No MBID for : Lil Mariko
# {   'Fenne Lily': None,
#     'LIL BO WEEP': None,
#     'LIL BOODANG': None,
#     'LIL DUSTY G': None,
#     'LIL GNAR': None,
#     'LIL PEEP': None,
#     'LIL PUMP': None,
#     'LIL TRACY': None,
#     'LIL UZI VERT': None,
#     'Lil B': '1550f952-c91b-40d7-9b4d-d26a259ee932',
#     'Lil Baby': None,
#     'Lil Candy Paint': None,
#     'Lil Darkie': None,
#     'Lil Dicky': '3268f062-6e76-480a-a384-e1dd2a276afb',
#     'Lil Double 0': None,
#     'Lil Durk': 'c9cd225b-4883-428e-82c2-73e0b6282fb6',
#     'Lil Eazzyy': None,
#     'Lil God Dan': None,
#     'Lil Hero': None,
#     'Lil Jon': 'a95384b1-6aec-468c-ae0d-8c6daf87c4c2',
#     'Lil Jon ': None,
#     'Lil Keed': None,
#     'Lil Kleine': None,
#     'Lil Loaded': None,
#     'Lil Mariko': None,
#     'Lil Nas X': None,
#     'Lil O': None,
#     'Lil Revive': None,
#     'Lil Shine': 'd4c7d574-c8f8-4c7e-ab45-fc612df367ca',
#     'Lil Tecca': None,
#     'Lil Tony Official': None,
#     'Lil Ugly Mane': '5f1adfe1-4d07-4141-b181-79e5d379d539',
#     'Lil Wayne': 'ac9a487a-d9d2-4f27-bb23-0f4686488345',
#     'Lil Xan': None,
#     'Lil Yachty': None,
#     "Lil' Kim": 'bc1b5c95-e6d6-46b5-957a-5e8908b02c1e',
#     "Lil' Wayne": None,
#     'Lilac': '1967c6ce-95a4-48f0-8ac7-abe637524aee',
#     'Lilly Wood ': None,
#     'Lilly Wood and The Prick': None,
#     'Lily Allen': '6e0c7c0e-cba5-4c2c-a652-38f71ef5785d',
#     'Lily Chou-Chou': '5652bb3e-f225-49de-9637-5aa1539b4a7c',
#     'Lily James': None,
#     'Lilypichu': None,
#     'lil Mosey': None,
#     'lil mabu': None,
#     'lil skies': None,
#     'lil tjay': None,
#     'lilbubblegum': None,
#     'lilgiela33': None}

# %% [markdown]
# ## 5) Find the artist's name and bio using their `mbid`.
#
# It can either be Lil Jon or whoever you selected above.
#
# If you look at the [last.fm documentation](http://www.last.fm/api/show/artist.getInfo), you can see how to use the artist's `mbid` to find more information about them. Print **every tag associated with your artist**.
#
# - *Tip: It's a new request to the API*
# - *Tip: Use the `mbid`, and make sure you delete the `&name=Cher` from the sample endpoint*
# - *Tip: If you use `print` for the bio it looks a little nicer than it would otherwise*

# %%
# Find Lil Jon MBID
mbid_lil_jon = mbid_dict['Lil Jon']
# print(mbid_lil_jon)

# %%
# " /2.0/?method=artist.getinfo&artist=Cher&api_key=YOUR_API_KEY&format=json"

url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid={mbid_lil_jon}&api_key={API_LAST_FM}&format=json"
# print(url)

response = requests.get(url)

data_lil_jon = response.json()
data_lil_jon
# Out:
# {'artist': {'name': 'Lil Jon',
#   'mbid': 'a95384b1-6aec-468c-ae0d-8c6daf87c4c2',
#   'url': 'https://www.last.fm/music/Lil+Jon',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': ''}],
#   'streamable': '0',
#   'ontour': '0',
#   'stats': {'listeners': '777796', 'playcount': '4597471'},
#   'similar': {'artist': [{'name': 'Lil Jon & The East Side Boyz',
#      'url': 'https://www.last.fm/music/Lil+Jon+&+The+East+Side+Boyz',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Ying Yang Twins',
#      'url': 'https://www.last.fm/music/Ying+Yang+Twins',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'LMFAO',
#      'url': 'https://www.last.fm/music/LMFAO',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Lil Scrappy',
#      'url': 'https://www.last.fm/music/Lil+Scrappy',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Dem Franchize Boyz',
#      'url': 'https://www.last.fm/music/Dem+Franchize+Boyz',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]}]},
#   'tags': {'tag': [{'name': 'Crunk', 'url': 'https://www.last.fm/tag/Crunk'},
#     {'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'},
#     {'name': 'rap', 'url': 'https://www.last.fm/tag/rap'},
#     {'name': 'Dirty South', 'url': 'https://www.last.fm/tag/Dirty+South'},
#     {'name': 'hip hop', 'url': 'https://www.last.fm/tag/hip+hop'}]},
#   'bio': {'links': {'link': {'#text': '',
#      'rel': 'original',
#      'href': 'https://last.fm/music/Lil+Jon/+wiki'}},
#    'published': '28 Jul 2006, 14:04',
#    'summary': 'Jonathan Mortimer Smith (born January 27, 1971 in Atlanta, Georgia), better known by his stage name Lil Jon, is an American rapper, actor, producer and member of the crunk group Lil Jon & The East Side Boyz. Lil Jon formed the group with friends Big Sam and Lil Bo, and they released five studio albums and have had many hit songs. He\'s prehaps best known for his iconic single "Get Low", which featured the Ying Yang Twins and reached #2 on the Billboard 100. He released his debut solo album, \'Crunk Rock\', in June 2010. <a href="https://www.last.fm/music/Lil+Jon">Read more on Last.fm</a>',
#    'content': 'Jonathan Mortimer Smith (born January 27, 1971 in Atlanta, Georgia), better known by his stage name Lil Jon, is an American rapper, actor, producer and member of the crunk group Lil Jon & The East Side Boyz. Lil Jon formed the group with friends Big Sam and Lil Bo, and they released five studio albums and have had many hit songs. He\'s prehaps best known for his iconic single "Get Low", which featured the Ying Yang Twins and reached #2 on the Billboard 100. He released his debut solo album, \'Crunk Rock\', in June 2010.\n\nLil Jon has also produced many hit urban singles and has made the terms "OK!", "What?!", and "Yeah!" a familiar calling among his friends and followers both inside and outside of the hip-hop genre. He\'s provided guest verses in many hip-hop and rnb tracks by a wide variety of artists as well. In terms of his personal life, he married Nicole Smith in 2004. They have a son named Nathan, who was born in 1998.\n\nLil Jon was born and raised in Atlanta, Georgia. He worked for So So Def Recordings between 1993 and 2000.\n\nIn addition to leading Lil Jon & The East Side Boyz, Lil Jon has also produced many hit urban singles. From 2003 to 2005, while still with The East Side Boyz, Lil Jon produced hits like "Salt Shaker" by Ying Yang Twins, "Yeah!" by Usher, Freek-a-Leek by Petey Pablo, Shorty Wanna Ride by Young Buck, Shake That Monkey by Too $hort, Let\'s Go by Trick Daddy, and Girlfight by Brooke Valentine. Lil Jon entered the San Francisco Bay Area hyphy music scene in 2006 with his collaborations with Bay Area rapper E-40, Lil Jon produced E-40\'s single "Tell Me When To Go" and had E-40 and Atlanta rapper Sean P on his own "Snap Yo Fingers".\n\nIn 2006, Lil\' Jon severed his negotiation with record label TVT. He vowed never to record for TVT Records again, alleging that TVT owner Steve Gottlieb was shortchanging him. He also began recording a rock music album, Crunk Rock; in May 2006 he began recording in Las Vegas, Nevada because rock band The Killers was recording its upcoming album Sam\'s Town there.\n\nMTV News reported in March 2008 that Crunk Rock was taking more time to complete than Lil\' Jon already planned. As part of TVT Records\' 2008 bankruptcy auction, Lil\' Jon withdrew his multi-million dollar objection to the TVT sale proceedings and agreed to TVT’s transfer of his artist agreement to The Orchard. In return, The Orchard released Lil\' Jon from all future obligations and returned the rights to the master recordings of Crunk Rock.\n\nWebsite: https://myspace.com/liljon <a href="https://www.last.fm/music/Lil+Jon">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.'}}}

# %%
bio = data_lil_jon['artist']['bio']['content']
print(bio)
print("_____")

for tag in data_lil_jon['artist']['tags']['tag']:
    tags_item = tag['name']
    print("***")
    print(tags_item)
# Out:
# Jonathan Mortimer Smith (born January 27, 1971 in Atlanta, Georgia), better known by his stage name Lil Jon, is an American rapper, actor, producer and member of the crunk group Lil Jon & The East Side Boyz. Lil Jon formed the group with friends Big Sam and Lil Bo, and they released five studio albums and have had many hit songs. He's prehaps best known for his iconic single "Get Low", which featured the Ying Yang Twins and reached #2 on the Billboard 100. He released his debut solo album, 'Crunk Rock', in June 2010.
#
# Lil Jon has also produced many hit urban singles and has made the terms "OK!", "What?!", and "Yeah!" a familiar calling among his friends and followers both inside and outside of the hip-hop genre. He's provided guest verses in many hip-hop and rnb tracks by a wide variety of artists as well. In terms of his personal life, he married Nicole Smith in 2004. They have a son named Nathan, who was born in 1998.
#
# Lil Jon was born and raised in Atlanta, Georgia. He worked for So So Def Recordings between 1993 and 2000.
#
# In addition to leading Lil Jon & The East Side Boyz, Lil Jon has also produced many hit urban singles. From 2003 to 2005, while still with The East Side Boyz, Lil Jon produced hits like "Salt Shaker" by Ying Yang Twins, "Yeah!" by Usher, Freek-a-Leek by Petey Pablo, Shorty Wanna Ride by Young Buck, Shake That Monkey by Too $hort, Let's Go by Trick Daddy, and Girlfight by Brooke Valentine. Lil Jon entered the San Francisco Bay Area hyphy music scene in 2006 with his collaborations with Bay Area rapper E-40, Lil Jon produced E-40's single "Tell Me When To Go" and had E-40 and Atlanta rapper Sean P on his own "Snap Yo Fingers".
#
# In 2006, Lil' Jon severed his negotiation with record label TVT. He vowed never to record for TVT Records again, alleging that TVT owner Steve Gottlieb was shortchanging him. He also began recording a rock music album, Crunk Rock; in May 2006 he began recording in Las Vegas, Nevada because rock band The Killers was recording its upcoming album Sam's Town there.
#
# MTV News reported in March 2008 that Crunk Rock was taking more time to complete than Lil' Jon already planned. As part of TVT Records' 2008 bankruptcy auction, Lil' Jon withdrew his multi-million dollar objection to the TVT sale proceedings and agreed to TVT’s transfer of his artist agreement to The Orchard. In return, The Orchard released Lil' Jon from all future obligations and returned the rights to the master recordings of Crunk Rock.
#
# Website: https://myspace.com/liljon <a href="https://www.last.fm/music/Lil+Jon">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.
# _____
# ***
# Crunk
# ***
# Hip-Hop
# ***
# rap
# ***
# Dirty South
# ***
# hip hop

# %%
# # pprint(data_lil_jon, indent=4)
# data_lil_jon['artist']['tags']['tag']

# %% [markdown]
# ## 6) Print every tag of that artist

# %%
for tag in data_lil_jon['artist']['tags']['tag']:
    tags_item = tag['name']
    print("***")
    print(tags_item)
# Out:
# ***
# Crunk
# ***
# Hip-Hop
# ***
# rap
# ***
# Dirty South
# ***
# hip hop

# %% [markdown]
# # GETTING A LITTLE CRAZY
#
# So you know your original list of musicians? I want to get tag data for ALL OF THEM. How are we going to do that?
#
# ## 7) Find the mbids (again)
#
# If we have a musician with an mbid of `AAA-AAA-AAA`, we get their info from a url like `http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=AAA-AAA-AAA`.
#
# |artist|url|
# |---|---|
# |`AAA-AAA-AAA`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=AAA-AAA-AAA`|
# |`BBB-BBB-BBB`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=BBB-BBB-BBB`|
# |`CCC-CCC-CCC`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=CCC-CCC-CCC`|
#
# I guess we should start trying to get a list of all of the mbids.
#
# **Loop through your artists, and print out the `mbid` for each artist**
#
# - *Tip: You probably need to request your artist search result data again, because you probably saved over `data` with your other API request. Maybe call it `artist_data` this time?*
# - *Tip: If the artist does NOT have an `mbid`, don't print it.*

# %%
# ONLY FOR ARTISTS WITH MBID
# mbids = []

# for artist_data in mbid_dict.values():
#     if artist_data is not None:
#         print(artist_data)
#         mbids.append(artist_data)
# Out:
# ac9a487a-d9d2-4f27-bb23-0f4686488345
# 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# c9cd225b-4883-428e-82c2-73e0b6282fb6
# 5f1adfe1-4d07-4141-b181-79e5d379d539
# 1550f952-c91b-40d7-9b4d-d26a259ee932
# d4c7d574-c8f8-4c7e-ab45-fc612df367ca
# 5652bb3e-f225-49de-9637-5aa1539b4a7c
# 3268f062-6e76-480a-a384-e1dd2a276afb
# bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# 1967c6ce-95a4-48f0-8ac7-abe637524aee
# a95384b1-6aec-468c-ae0d-8c6daf87c4c2

# %%
mbids = []
other_name = []

for artist_name, artist_data in mbid_dict.items():
    if artist_data is not None:
        # print(f"{artist_name} = {artist_data}")
        mbids.append(artist_data)
    else:
        name = artist_name
        name_clean = name.lower().replace(" ", "+")
        other_name.append(name_clean)
# Out:
# Lil Wayne = ac9a487a-d9d2-4f27-bb23-0f4686488345
# Lily Allen = 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# Lil Durk = c9cd225b-4883-428e-82c2-73e0b6282fb6
# Lil Ugly Mane = 5f1adfe1-4d07-4141-b181-79e5d379d539
# Lil B = 1550f952-c91b-40d7-9b4d-d26a259ee932
# Lil Shine = d4c7d574-c8f8-4c7e-ab45-fc612df367ca
# Lily Chou-Chou = 5652bb3e-f225-49de-9637-5aa1539b4a7c
# Lil Dicky = 3268f062-6e76-480a-a384-e1dd2a276afb
# Lil' Kim = bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# Lilac = 1967c6ce-95a4-48f0-8ac7-abe637524aee
# Lil Jon = a95384b1-6aec-468c-ae0d-8c6daf87c4c2

# %% [markdown]
# ## 8) Saving those mbids
#
# For those `mbid` values, instead of printing them out, save them to a new list of just mbid values. Call this list `mbids`.
#
# - *Tip: Use `.append` to add a single element onto a list*

# %% [markdown]
# Your results should look something like
#
# ```['6e0c7c0e-cba5-4c2c-a652-38f71ef5785d',
#  '1550f952-c91b-40d7-9b4d-d26a259ee932',
#  '1b72331b-3a97-4981-a81c-eeee9c275d28',
#  '5f1adfe1-4d07-4141-b181-79e5d379d539',
#  'a95384b1-6aec-468c-ae0d-8c6daf87c4c2',
#  'bc1b5c95-e6d6-46b5-957a-5e8908b02c1e',
#  '243c6f61-d83b-4459-bebd-5899df0da111',
#  '8ba17cf6-bec2-4ae4-9820-b1cda47adc08',
#  'ad29ae1c-2eda-4071-9dc8-31910e7e546c',
#  '3268f062-6e76-480a-a384-e1dd2a276afb',
#  '3ad4f6ec-253f-4050-8849-ca26266edfb8',
#  '9b5ce0c1-1bc0-4ea2-a8d3-f5ee7af9eda8',
#  '981d39fc-bd00-4cc6-ac67-6410f8b89098',
#  'b89f4c50-72f5-48ce-b08c-a643b191b24f',
#  'bc21df5c-3d79-479b-b638-8ddb5ecea403',
#  'c9cd225b-4883-428e-82c2-73e0b6282fb6',
#  '9acaf734-b380-4c48-954c-a2cf1d7990a9',
#  'd4d5ae85-700c-4a55-8a39-7f923da07ef2',
#  '77fafce8-a32f-4d42-bdce-266bbf913cee',
#  '50ad1cde-1536-4268-a55f-e47a7b8280ab',
#  '9803d120-716d-45ba-9eb7-9a120813f908',
#  'b27560ea-2783-4a91-be45-9e8711917562',
#  '194e87c9-b3fe-4fbd-82a7-8c54b4dd4c76',
#  'fd90af91-ed07-4e85-8816-26c954fe5286',
#  '5652bb3e-f225-49de-9637-5aa1539b4a7c']```

# %% [markdown]
# ## 9) Printing our API urls
#
# To get tag data for each artist, you need to use those `mbid` values to access their artist page on the API. Loop through the mbids, displying the URL you'll need to access.
#
# - *Tip: You don't want to use a comma when printing, because commas add spaces into your text and URLs can't have that*
# - *Tip: Make sure your URL has `artist.getinfo` in it - if not, you're using the wrong endpoint.*

# %%
# mbids = []
# other_name = []

# Two URL lists, one with mbid, one with name

url_artists_mbid = []
url_artists_others = []

for artist in mbids:
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid={artist}&api_key={API_LAST_FM}&format=json"
    # print(url)
    url_artists.append(url)

for artist in other_name:
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artist}&api_key={API_LAST_FM}&format=json"
    # print(url)
    url_artists_others.append(url)


# Joining the two lists
url_artists = url_artists_mbid + url_artists_others
# Out:
# ['http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+uzi+vert&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+peep&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+baby&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+tecca&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+yachty&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+nas+x&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+tjay&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+darkie&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  "http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil'+wayne&api_key=99f32782a7be8554947b8c349742ead2&format=json",
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+skies&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+mosey&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+tracy&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+pump&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+keed&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+mabu&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+loaded&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+xan&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lilbubblegum&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lilypichu&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+gnar&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+revive&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+jon+&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+hero&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+dusty+g&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+double+0&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+tony+official&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+kleine&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lilgiela33&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lilly+wood+and+the+prick&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+eazzyy&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+candy+paint&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lilly+wood+&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+bo+weep&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=fenne+lily&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+boodang&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+god+dan&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+o&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lily+james&api_key=99f32782a7be8554947b8c349742ead2&format=json',
#  'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+mariko&api_key=99f32782a7be8554947b8c349742ead2&format=json']

# %% [markdown]
# Your results should look something like
#
# ```http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=1550f952-c91b-40d7-9b4d-d26a259ee932
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=1b72331b-3a97-4981-a81c-eeee9c275d28
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=5f1adfe1-4d07-4141-b181-79e5d379d539
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=bc1b5c95-e6d6-46b5-957a-5e8908b02c1e```

# %% [markdown]
# ## OKAY HERE IS A LITTLE INFORMATION: Using our API urls
#
# This time instead of just *displaying* the URL, we're going to *request and process it*. **But first I'm going to teach you something.**
#
# When you're dealing with an API, you don't want to make a million requests, have bad code, and then need to do those million requests again. It's usually best to test your code with a few of the results first.
#
# So, if we have a list of numbers like this:

# %%
# numbers = [4, 5, 6, 7]
# numbers

len(url_artists)
# Out:
# 39

# %% [markdown]
# You can actually say to Python, **give me the first two**, and it will only give you the first two.

# %%
numbers[:2]

# %% [markdown]
# The is **very convenient** with loopng with APIs, because instead of trying to use all FIFTY artists, you can just say "hey, please try this out with 2 of them" and you don't waste time.

# %% [markdown]
# ## 10) Using the first three `mbids`, request the API urls and print the artist's name.
#
# You built the URLs in the last question, now it's time to use them! Use `requests` etc to grab the URL and get out the artist's name.
#
# - *Tip: The code is the same as last time you got an artist's name from their info page, it's just going to be inside of a loop*
# - *Tip: USE `PRINT` TO SEE WHAT YOU ARE LOOKING AT!!!!!*

# %%
url_artists_sample = url_artists[:3]

for artist in url_artists_sample:
    print("____")
    print(artist)
    response = requests.get(artist)
    artist_infos = response.json()
    name = artist_infos['artist']['name']
    print(name)
# Out:
# ____
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+uzi+vert&api_key=99f32782a7be8554947b8c349742ead2&format=json
# LIL UZI VERT
# ____
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+peep&api_key=99f32782a7be8554947b8c349742ead2&format=json
# LIL PEEP
# ____
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+baby&api_key=99f32782a7be8554947b8c349742ead2&format=json
# Lil Baby

# %% [markdown]
# ## 11) Using the first three `mbids`, request the API urls and print the artist's name and their tags
#
# - *Tip: The code is the same as last time you got an artist's name from their info page, it's just going to be inside of a loop*
# - *Tip: It's a for loop in a for loop!*

# %%
for artist in url_artists_sample:
    print("____")
    print(artist)
    response = requests.get(artist)
    artist_infos = response.json()
    name = artist_infos['artist']['name']
    print(name)
    print("***")
    tags = artist_infos['artist']['tags']['tag']
    for tag in tags:
        tag_name = tag['name']
        print(tag_name)
# Out:
# ____
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+uzi+vert&api_key=99f32782a7be8554947b8c349742ead2&format=json
# LIL UZI VERT
# ***
# trap
# rap
# Hip-Hop
# hip hop
# emo rap
# ____
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+peep&api_key=99f32782a7be8554947b8c349742ead2&format=json
# LIL PEEP
# ***
# cloud rap
# emo rap
# Hip-Hop
# rap
# emo
# ____
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=lil+baby&api_key=99f32782a7be8554947b8c349742ead2&format=json
# Lil Baby
# ***
# rap
# Hip-Hop
# hip hop
# trap
# atlanta

# %% [markdown]
# ## 12) Using the first ten mbids, print the artist's name and whether they're a rapper
#
# Only print their name ONCE and only print whether they are hip hop or not ONCE.
#
# - *Tip: Rap tags include hip hop, swag, crunk, rap, dirty south, and probably a bunch of other stuff! You can include as many categories as you'd like.*
# - *Tip: You can use `2 in [1, 2, 3]` to find out if `2` is in the list of `[1, 2, 3]`.*
# - *Tip: Every time you look at a new artist, you can say they are NOT a rapper. And once you find out one of their tags is hip hop or rap, then you can note that they're a rapper. Then once you're done looking at their tags, then you can say HEY this is a rapper, or HEY this is not a rapper.*

# %%
url_artists_sample = url_artists[:10]

rapper_tag = ["rap", "hip hop", "swag", "crunk", "dirty south"]

for artist in url_artists_sample:
    print("____")
    # print(artist)
    response = requests.get(artist)
    artist_infos = response.json()
    
    name = artist_infos['artist']['name']
    is_rapper = False

    tags = artist_infos['artist']['tags']['tag']
    for tag in tags:
        tag_name = tag['name']
        # print(tag_name)
        if tag_name in rapper_tag:
            is_rapper = True
    
    print(name)
    print(f"Can we call it rap? {is_rapper}")
# Out:
# ____
# LIL UZI VERT
# Can we call it rap? True
# ____
# LIL PEEP
# Can we call it rap? True
# ____
# Lil Baby
# Can we call it rap? True
# ____
# Lil Tecca
# Can we call it rap? True
# ____
# Lil Yachty
# Can we call it rap? True
# ____
# Lil Nas X
# Can we call it rap? True
# ____
# lil tjay
# Can we call it rap? True
# ____
# Lil Darkie
# Can we call it rap? True
# ____
# Lil' Wayne
# Can we call it rap? True
# ____
# lil skies
# Can we call it rap? True

# %% [markdown]
# Your results might look something like
#
# ```ARTIST: Lily Allen
# NO hip hop
# ARTIST: Lil B
# YES hip hop
# ARTIST: Lilly Wood & The Prick
# NO hip hop
# ARTIST: Lil Ugly Mane
# YES hip hop
# ARTIST: Lil Jon
# YES hip hop
# ARTIST: Lil' Kim
# YES hip hop
# ARTIST: Lil Jon & The East Side Boyz
# YES hip hop
# ```

# %% [markdown]
# ## 13) What percent of "lil" results are rappers?

# %%
count_rapper = 0

for artist in url_artists:
    # print("____")
    # print(artist)
    response = requests.get(artist)
    artist_infos = response.json()
    
    name = artist_infos['artist']['name']
    is_rapper = False

    tags = artist_infos['artist']['tags']['tag']
    for tag in tags:
        tag_name = tag['name']
        # print(tag_name)
        if tag_name in rapper_tag:
            is_rapper = True
    if is_rapper == True:
        count_rapper += 1

# print(count_rapper)
print(f"The proportion of rappers is {count_rapper / len(url_artists) * 100:.1f}%.")
# Out:
# The proportion of rappers is 64.1.

# %% [markdown]
# ## 14) Seriously you are all-powerful now.
